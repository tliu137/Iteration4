# %%
import pandas as pd
path = "12files.csv"

# %%
data_set = pd.read_csv(path)

# %%
data_set.head(10)
# Out:
#    year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  \
# 0  2013      3    1     0    9.0   9.0   6.0  17.0  200.0  62.0   0.3  1021.9
# 1  2013      3    1     1   11.0  11.0   7.0  14.0  200.0  66.0  -0.1  1022.4
# 2  2013      3    1     2    8.0   8.0   NaN  16.0  200.0  59.0  -0.6  1022.6
# 3  2013      3    1     3    8.0   8.0   3.0  16.0    NaN   NaN  -0.7  1023.5
# 4  2013      3    1     4    8.0   8.0   3.0   NaN  300.0  36.0  -0.9  1024.1
# 5  2013      3    1     5   10.0  10.0   4.0   8.0  200.0  64.0  -1.6  1024.7
# 6  2013      3    1     6    8.0   8.0   6.0  13.0  300.0  61.0  -2.4  1025.4
# 7  2013      3    1     7    8.0   8.0   8.0  20.0  300.0  54.0  -0.8  1026.7
# 8  2013      3    1     8    3.0   6.0   9.0  23.0  300.0  50.0   0.4  1027.3
# 9  2013      3    1     9    3.0   6.0  10.0  18.0  300.0  56.0   1.5  1027.4
#
#    DEWP  RAIN   wd  WSPM        station
# 0 -19.0   0.0  WNW   2.0  Wanshouxigong
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(45,15))
sns.stripplot(x=data_set["hour"],y=data_set["PM2.5"],data =data_set,jitter = True )
plt.show()

# %%
plt.figure(figsize=(45,15))
sns.stripplot(x=data_set["RAIN"],y=data_set["PM2.5"],data =data_set,jitter = True )
plt.show()

# %%
sns.stripplot(x=data_set["wd"],y=data_set["PM2.5"],data =data_set,jitter = True )
plt.show()

# %%
plt.figure(figsize=(45,15))
sns.stripplot(x=data_set["WSPM"],y=data_set["PM2.5"],data =data_set,jitter = True )
plt.show()

# %%
plt.figure(figsize=(45,15))
sns.stripplot(x=data_set["CO"],y=data_set["PM2.5"],data =data_set,jitter = True )
plt.show()

# %%
import seaborn as sns
from matplotlib import pyplot as plt
corrmat = data_set.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,15))
g=sns.heatmap(data_set[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
df2 = pd.read_csv("after_feature.csv")

# %%
df2.head(10)
# Out:
#    month   SO2   NO2   CO    O3  TEMP    PRES  DewPointTempeature  WindSpend  \
# 0      1  10.0  16.0  400  54.0  -1.0  1027.0               -23.0        0.9
# 1      1  11.0  17.0  400  53.0   0.0  1025.0               -22.9        2.7
# 2      1  10.0  15.0  400  55.0   0.0  1027.0               -22.9        2.4
# 3      1  13.0  13.0  400  57.0   0.0  1028.0               -24.4        2.4
# 4      1  15.0  12.0  400  58.0   0.0  1030.0               -24.4        2.4
# 5      1  13.0  15.0  500  55.0  -1.0  1024.0               -24.4        3.2
# 6      1  10.0  30.0  500  39.0  -4.0  1029.0               -24.3        0.9
# 7      1  10.0  41.0  600  30.0  -2.0  1029.0               -23.9        4.2
# 8      1  10.0  55.0  600  16.0  -2.0  1027.0               -23.9        1.9
# 9      1  11.0  56.0  600  17.0  -1.0  1026.0               -23.0        1.5
#
#    WindDirectionIndex  stationIndex  NQRIndex  SeasonIndex
# 0                   1             4         0            0
# ...

# %%
plt.figure(figsize=(45,15))
sns.stripplot(x=df2["NQRIndex"],y=df2["WindSpend"],data =df2,jitter = True )
plt.show()

# %%
plt.figure(figsize=(45,15))
sns.stripplot(x=df2["NQRIndex"],y=df2["DewPointTempeature"],data =df2,jitter = True )
plt.show()
